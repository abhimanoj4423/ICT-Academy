# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to python environment

# %%
iris=pd.read_csv(r"G:\course\ICT academy\Assignments\1\iris.csv")
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Classification'].value_counts()
# Out:
# Classification
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **Renaming columns for readability**

# %%
iris.rename(columns={'SL': 'Sepal Length', 'SW': 'Sepal Width','PL': 'Petal Length', 'PW': 'Petal Width'},inplace=True)

# %% [markdown]
# # 2. Display the columns in the dataset

# %%
list(iris.columns.values)
# Out:
# ['Sepal Length',
#  'Sepal Width',
#  'Petal Length',
#  'Petal Width',
#  'Classification']

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
iris.describe().loc['mean']
# Out:
# Sepal Length    5.843333
# Sepal Width     3.054000
# Petal Length    3.758667
# Petal Width     1.198667
# Name: mean, dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
iris.isnull().sum()
# Out:
# Sepal Length      0
# Sepal Width       0
# Petal Length      0
# Petal Width       0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# ## **Finding Outliers**

# %%
plt.boxplot(iris[['Sepal Length','Sepal Width','Petal Length','Petal Width']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d665b97d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d668d4de50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d668cb6c50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d668d4f5d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d668d4ffd0>,
# ...
#  'means': []}

# %% [markdown]
# ## Relationship between **Sepal Length** and **Sepal Width**

# %%
colors = ['red','orange','blue']
j=0
groups = iris.groupby("Classification")
for key,i in groups:
    plt.scatter(i["Sepal Length"], i["Sepal Width"], c=colors[j], label=key,marker='^')
    j=j+1
plt.legend()
plt.title("Relationship between Sepal Length and Sepal Width",fontsize=14)
plt.xlabel("Sepal Length in cm")
plt.ylabel("Sepal Width in cm")
# Out:
# Text(0, 0.5, 'Sepal Width in cm')

# %% [markdown]
# ## Relationship between **Petal Length** and **Petal Width**

# %%
colors = ['red','orange','blue']
j=0
groups = iris.groupby("Classification")
for key,i in groups:
    plt.scatter(i["Petal Length"], i["Petal Width"], c=colors[j], label=key,marker='^')
    j=j+1
plt.legend()
plt.title("Relationship between Petal Length and Petal Width",fontsize=14)
plt.xlabel("Petal Length in cm")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %% [markdown]
# ## Relationship between **Petal Length** and **Sepal Length**

# %%
colors = ['red','orange','blue']
j=0
groups = iris.groupby("Classification")
for key,i in groups:
    plt.scatter(i["Petal Length"], i["Sepal Length"], c=colors[j], label=key,marker='^')
    j=j+1
plt.legend()
plt.title("Relationship between Petal Length and Sepal Length",fontsize=14)
plt.xlabel("Petal Length in cm")
plt.ylabel("Sepal Length in cm")
# Out:
# Text(0, 0.5, 'Sepal Length in cm')

# %% [markdown]
# ## Correlation between the metrices

# %%
slice_data=iris[['Sepal Length','Sepal Width','Petal Length','Petal Width']]

# %%
sns.heatmap(slice_data.corr(),annot=True,cmap="cubehelix")
# Out:
# <Axes: >
